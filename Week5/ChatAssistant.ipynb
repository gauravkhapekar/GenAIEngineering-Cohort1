# %% [markdown]
# # **Building a Retrieval Augmented Generation (RAG) Based AI Chatbot**
#
# ## **1. Introduction to RAG**
#
# Retrieval Augmented Generation (RAG) is a powerful architectural pattern for building AI chatbots and other language model applications that can leverage external knowledge sources to provide more accurate, up-to-date, and contextually relevant responses.
#
# Traditional Large Language Models (LLMs) are trained on vast datasets, but their knowledge is static (frozen at the time of training) and they can sometimes "hallucinate" or generate plausible but incorrect information. RAG addresses these limitations by:
#
# 1. **Retrieving** relevant information from a specified knowledge base in real-time.
# 2. **Augmenting** the user's query with this retrieved information.
# 3. **Generating** a response based on both the original query and the augmented context.
#
# This allows the chatbot to access and utilize domain-specific, private, or rapidly changing information that was not part of its original training data.
#
# ## **2. Core Components of a RAG System**
#
# A typical RAG system comprises several key components:
#
# * **Knowledge Base (Data Corpus):** This is the collection of documents, data, or information that the chatbot will use to answer questions. It can be a set of text files, PDFs, web pages, database records, FAQs, articles, etc.
# * **Embedding Model:** This model converts text (from the knowledge base and user queries) into numerical representations called "embeddings" or "vectors." These embeddings capture the semantic meaning of the text, allowing for similarity comparisons. Popular choices include models like Sentence-BERT, OpenAI's Ada, or Cohere's embed models.
# * **Vector Database (Vector Store):** This specialized database is designed to store and efficiently query high-dimensional vectors (the embeddings). It allows for fast similarity searches to find the most relevant pieces of information from the knowledge base based on a query embedding. Examples include Pinecone, Weaviate, FAISS, Chroma, Milvus, or even some traditional databases with vector search capabilities.
# * **Retriever:** This component takes the user's query, converts it into an embedding using the embedding model, and then queries the vector database to find the "top-k" most similar document chunks or pieces of information from the knowledge base.
# * **Large Language Model (LLM) \- The Generator:** This is the core generative model (e.g., GPT-3.5/4, Llama, PaLM, Claude) that takes the original user query *and* the retrieved context (from the Retriever) and generates a coherent, natural language response.
# * **Orchestration/Prompting Layer:** This layer manages the overall workflow. It formats the user's query and the retrieved context into a suitable prompt for the LLM, ensuring the LLM understands how to use the provided information to answer the question.
#
# ## **3. Workflow of a RAG Chatbot**
#
# The typical interaction flow in a RAG chatbot is as follows:
#
# 1. **User Query:** The user asks the chatbot a question.
# 2. **Query Embedding:** The user's query is converted into a vector embedding by the embedding model.
# 3. **Information Retrieval:**
#    * The retriever uses this query embedding to search the vector database.
#    * The vector database returns the most semantically similar document chunks (contexts) from the knowledge base.
# 4. **Context Augmentation & Prompting:**
#    * The retrieved context(s) are combined with the original user query.
#    * This combined information is formatted into a prompt that instructs the LLM to answer the query based on the provided context.
# 5. **Response Generation:** The LLM processes the augmented prompt and generates a natural language response.
# 6. **User Receives Response:** The chatbot presents the LLM's generated answer to the user.
#
# ## **4. Steps to Build a RAG Chatbot**
#
# Building a RAG chatbot involves several key development stages:
#
# ### **Step 1: Data Preparation & Loading**
#
# * **Gather Your Data:** Collect all the documents and data sources that will form your knowledge base.
# * **Preprocess Data:** Clean the data (remove irrelevant characters, formatting issues).
# * **Chunking:** This is a crucial step. LLMs have context window limits. Large documents need to be broken down into smaller, manageable, and semantically coherent chunks. The size of these chunks can impact retrieval quality.
#   * **Strategies:** Fixed-size chunking, sentence-based chunking, recursive chunking, or content-aware chunking (e.g., by paragraphs or sections).
#   * **Overlap:** Often, a small overlap between chunks is introduced to ensure semantic continuity is not lost at chunk boundaries.
#
# ### **Step 2: Embedding Generation & Storage**
#
# * **Choose an Embedding Model:** Select an embedding model appropriate for your data and language.
# * **Generate Embeddings:** Process each chunk of your knowledge base through the embedding model to create its vector representation.
# * **Set up Vector Database:** Choose and configure a vector database.
# * **Index Embeddings:** Store these embeddings (along with their corresponding text chunks and any metadata) in the vector database, creating an index for efficient searching.
#
# ### **Step 3: Implement the Retriever**
#
# * **Query Embedding Function:** Create a function that takes a user query, uses the same embedding model from Step 2, and generates its embedding.
# * **Similarity Search Function:** Implement logic to take the query embedding and perform a similarity search (e.g., cosine similarity, dot product) against the indexed embeddings in the vector database. This function should return the top-k most relevant text chunks.
#
# ### **Step 4: Integrate the Large Language Model (Generator)**
#
# * **Choose an LLM:** Select an LLM suitable for your chatbot's desired capabilities and tone (e.g., OpenAI's API, a self-hosted open-source model).
# * **Prompt Engineering:** This is critical. Design a prompt template that effectively combines the user's original query with the retrieved context. The prompt should guide the LLM to:
#   * Answer the question based *only* on the provided context if possible.
#   * Indicate if the answer cannot be found in the context.
#   * Maintain a conversational tone.
#   * Example Prompt Snippet:
#
# ```
#
# Context:
# {retrieved_document_chunks}
#
# Question: {user_query}
#
# Answer the question based on the context provided above. If the context doesn't contain the answer, say "I don't have enough information to answer that."
#
# ```
#
# ### **Step 5: Build the Chat Interface & Orchestration**
#
# * **User Interface (UI):** Develop a front-end for users to interact with the chatbot (e.g., a web interface, integration into an existing messaging platform).
# * **Backend Logic (Orchestration):** Create the backend logic that ties all components together:
#   1. Receives user query from the UI.
#   2. Calls the retriever to get relevant context.
#   3. Constructs the prompt for the LLM.
#   4. Sends the prompt to the LLM API.
#   5. Receives the LLM's response.
#   6. Sends the response back to the UI.
# * **Conversation History (Optional but Recommended):** For multi-turn conversations, you might want to include conversation history in the prompt or use techniques to summarize past turns to provide context for follow-up questions.
#
# ## **5. Key Considerations and Best Practices**
#
# * **Chunking Strategy:** Experiment with different chunk sizes and overlap. Too small, and you lose context; too large, and you might introduce noise or exceed LLM context limits.
# * **Embedding Model Choice:** The quality of embeddings significantly impacts retrieval. Choose models trained on similar domains or fine-tune them if necessary.
# * **Retrieval Strategy:**
#   * **Top-k:** How many chunks to retrieve? Too few might miss the answer; too many can overwhelm the LLM or dilute the relevant information.
#   * **Similarity Threshold:** Only retrieve chunks above a certain similarity score to filter out irrelevant results.
#   * **Re-ranking:** Sometimes, a secondary, more sophisticated model (a re-ranker) is used to re-order the initial top-k retrieved chunks for better relevance before sending them to the LLM.
# * **Prompt Engineering:** Iteratively refine your prompts. The way you instruct the LLM to use the context is crucial for response quality and preventing hallucinations.
# * **Evaluation:**
#   * **Retrieval Metrics:** Precision, Recall, Mean Reciprocal Rank (MRR) for the retriever.
#   * **Generation Metrics:** BLEU, ROUGE (less ideal for conversational AI), or human evaluation for the generated responses.
#   * **End-to-End Evaluation:** Assess the overall quality, relevance, and factuality of the chatbot's answers. Frameworks like RAGAs can be helpful.
# * **Handling "I don't know":** Ensure your system can gracefully handle queries for which no relevant information exists in the knowledge base, rather than forcing an answer.
# * **Scalability:** Consider the scalability of your vector database and LLM inference as your knowledge base and user traffic grow.
# * **Maintenance & Updates:** Plan how you will update the knowledge base, re-generate embeddings, and re-index the vector database as new information becomes available.
# * **Cost Management:** Using LLM APIs and vector databases can incur costs. Optimize your system for efficiency.
#
# ## **6. Benefits of RAG**
#
# * **Reduced Hallucinations:** By grounding responses in retrieved factual data, RAG significantly reduces the likelihood of the LLM making things up.
# * **Access to Current Information:** LLMs can answer questions based on the latest information available in the knowledge base, unlike their static training data.
# * **Domain-Specific Knowledge:** Enables chatbots to become experts in specific domains by feeding them relevant documents (e.g., medical texts, legal documents, internal company policies).
# * **Transparency and Explainability:** It's often possible to cite the source documents used to generate an answer, increasing trust and allowing users to verify information.
# * **Cost-Effective Customization:** Less expensive than fine-tuning an entire LLM for a new domain, as it primarily involves managing and embedding the knowledge base.
#
# ## **7. Potential Challenges**
#
# * **Retrieval Quality:** The entire system heavily relies on the retriever's ability to find the truly relevant information. Poor retrieval leads to poor generation.
# * **Chunking Dilemmas:** Finding the optimal chunking strategy can be challenging and data-dependent.
# * **Integration Complexity:** Connecting various components (embedding models, vector DBs, LLMs) requires careful engineering.
# * **Latency:** The multi-step process (embedding, retrieval, generation) can introduce latency. Optimizations are often needed.
# * **Evaluation Complexity:** Evaluating the end-to-end performance of RAG systems comprehensively can be difficult.

# %% [markdown]
# The pre-req steps to use the Gemini API key with Python:
#
# 1.  **Get API Key:** Go to [aistudio.google.com](https://aistudio.google.com/), sign in, and create/copy your API key (secure it immediately).
# 2.  **Install Library:** In your terminal, run `pip install -q -U google-generativeai`.
# 3.  **Set API Key Securely:**
#     * **Recommended:** Set it as an environment variable (e.g., `export GOOGLE_API_KEY="YOUR_KEY"` in terminal/shell config).
#     * **Colab:** Use Colab Secrets to store `GOOGLE_API_KEY`.
# 4.  **Configure in Python:** In your script, retrieve the key (e.g., `os.getenv('GOOGLE_API_KEY')` or `userdata.get('GOOGLE_API_KEY')`) and then use `genai.configure(api_key=YOUR_KEY)`.
#
# [Gemini API Key](https://aistudio.google.com/u/1/apikey)

# %%
# Load data
# https://www.kaggle.com/datasets/fajobgiua/indian-food-dataset?resource=download
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import re
from tqdm.auto import tqdm
import json
import pandas as pd
from langchain_core.documents import Document
# Load models and Initialize Vector Store
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_qdrant import Qdrant  # Qdrant Vector Store Wrapper
import google.generativeai as genai
from dotenv import load_dotenv  # For loading API key from a .env file
import os
load_dotenv()

tqdm.pandas(desc="Generating Documents")

cleaning_pattern = r'[^a-zA-Z0-9]'

columns = ['TranslatedRecipeName', 'TranslatedIngredients',
           'PrepTimeInMins', 'CookTimeInMins', 'TotalTimeInMins', 'Servings',
           'Cuisine', 'Course', 'Diet', 'TranslatedInstructions', 'URL',
           'ComplexityLevel', 'MainIngredient']

doc_columns = ['score', 'page_content',]


def convert_to_doc(row):
    doc = Document(
        page_content=f'''
# Recipe Name: {row['TranslatedRecipeName']}
> URL: {row['URL']}

## Ingredients:

{row['TranslatedIngredients']}

## Instructions:

{row['TranslatedInstructions']}
''',
        metadata={
            'TranslatedRecipeName': row['TranslatedRecipeName'],
            'PrepTimeInMins': row['PrepTimeInMins'],
            'CookTimeInMins': row['CookTimeInMins'],
            'TotalTimeInMins': row['TotalTimeInMins'],
            'Servings': row['Servings'],
            'Cuisine': row['Cuisine'],
            'Course': row['Course'],
            'Diet': row['Diet'],
            'ComplexityLevel': row['ComplexityLevel'],
            'MainIngredient': row['MainIngredient'],
        }
    )

    return doc


def generate_metadata(search_query, llm):
    meta_prompt = f'''
    Given below the user request for queries, create metadata filter dictionary for the search.

    user query: {search_query}

    > provide only and only a simple phrase for the user query, do not add any other information or context.
    > this output will be used to filter the recipes.

    available metadata:
    - 'Cuisine': string: ['Indian', 'Kerala Recipes', 'Oriya Recipes', 'Continental',
        'Chinese', 'Konkan', 'Chettinad', 'Mexican', 'Kashmiri',
        'South Indian Recipes', 'North Indian Recipes', 'Andhra',
        'Gujarati Recipes']
    - 'Diet': string: ['Vegetarian', 'High Protein Vegetarian', 'Non Vegeterian',
        'Eggetarian', 'Diabetic Friendly', 'High Protein Non Vegetarian',
        'Gluten Free', 'Sugar Free Diet', 'No Onion No Garlic (Sattvic)',
        'Vegan']
    - 'ComplexityLevel': string: ['Medium', 'Hard']

    We can do exact match only.

    respond with a valid json dictionary, do not add any other information or context.
    '''

    resp = llm.generate_content(meta_prompt).text
    metadata = json.loads(resp.split(
        'json')[1].strip().split('```')[0].strip())

    return metadata


def rewrite_query(search_query, llm):
    prompt = f'''
    Given below the user request for queries regarding Indian food recipes, rephrase and expand the query to a more search friendly term.

    user query: {search_query}

    > provide only and only a simple phrase for the user query, do not add any other information or context.
    > this output will be used to search the database for recipes.
    '''
    resp = llm.generate_content(prompt).text
    return resp


def break_query(search_query, llm):
    subquery_prompt = f'''
    Given below the user request for queries, break down the query into multiple subqueries.
    user query: {search_query}
    > provide only and only a simple phrase for the user query, do not add any other information or context.
    > this output will be used to search the database for recipes.

    > respond with a valid json array of strings, do not add any other information or context.
    '''

    resp = llm.generate_content(subquery_prompt).text
    subqueries = json.loads(resp.split(
        'json')[1].strip().split('```')[0].strip())
    return subqueries


def rerank_results(
        search_query,
        searched_df,
        reranking_model
):
    new_doc_embeddings = np.array(
        reranking_model.embed_documents(searched_df.page_content)
    )

    query_embedding = np.array(
        reranking_model.embed_query(search_query)
    )

    similarity_scores = cosine_similarity(
        query_embedding.reshape(1, -1),
        new_doc_embeddings
    )
    searched_df['rerank_score'] = similarity_scores[0].tolist()
    return searched_df


def search(
        search_query,
        llm,
        vector_store,
        reranking_model,
        n_results=10,
        similarity_threshold=0.1,
        flag_rewrite_query=True,
        flag_ai_metadata=True,
        flag_break_query=True,
        flag_rerank_results=True,
):
    """
    Search for the given query in the vector store and return the top n results.
    """
    metadata = {}  # Empty metadata
    subqueries = [search_query]

    if flag_rewrite_query:
        search_query = rewrite_query(search_query, llm)

    if flag_ai_metadata:
        metadata = generate_metadata(search_query, llm)

    if flag_break_query:
        subqueries = break_query(search_query, llm)

    ret_docs = []

    for subquery in subqueries:
        ret_docs += vector_store.similarity_search_with_score(
            subquery,
            k=n_results,
            score_threshold=similarity_threshold,
            filter=metadata
        )

    searched_df = pd.DataFrame(
        [
            {
                'score': score,
                **doc.metadata,
                'page_content': doc.page_content,
            } for doc, score in ret_docs
        ],
        columns=doc_columns+columns
    )

    searched_df = searched_df.groupby(
        'TranslatedRecipeName').first().reset_index()
    searched_df['rerank_score'] = searched_df['score']

    if flag_rerank_results:
        searched_df = rerank_results(
            search_query,
            searched_df=searched_df,
            reranking_model=reranking_model,
        ).sort_values(
            'rerank_score',
            ascending=False,
        )

    return searched_df.head(n_results).round(2)[
        [
            'TranslatedRecipeName',
            'page_content',
            'PrepTimeInMins',
            'CookTimeInMins',
            'TotalTimeInMins',
            'Servings',
            'Cuisine',
            'Diet',
            'ComplexityLevel',
            'MainIngredient',
            'score',
            'rerank_score'
        ]
    ]


def as_cards(df):
    return df.apply(lambda x: x.to_markdown(), axis=1).to_list()


model_name = 'gemini-2.0-flash'

# %%
# Initialize system
api_key = os.getenv("GOOGLE_API_KEY")
genai.configure(api_key=api_key)


model = genai.GenerativeModel(model_name)

df = pd.read_csv('./IndianFoodDataset.csv', ).set_index('Srno')[columns]


data = df[:].progress_apply(convert_to_doc, axis=1)


model_768 = HuggingFaceEmbeddings(
    model_name="sentence-transformers/LaBSE",
)

model_384 = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
)

model_64 = HuggingFaceEmbeddings(
    model_name="ClovenDoug/tiny_64_all-MiniLM-L6-v2",
)


vector_store_unchunked = Qdrant.from_documents(
    data,
    model_384,
    collection_name="indian-food-metadata",
    location=':memory:',
)
# Out:
# Generating Documents:   0%|          | 0/6871 [00:00<?, ?it/s]

# %%
search_query = 'Healthy Non Veg, Non Spicy, Easy to Cook, 30 Mins, 2 Servings'
results = search(
    search_query,
    llm=model,
    reranking_model=model_768,
    vector_store=vector_store_unchunked,
    n_results=5,
    similarity_threshold=0.5,
    flag_rewrite_query=False,
    flag_ai_metadata=False,
    flag_break_query=False,
    flag_rerank_results=False,
)

results
# Out:
#                                 TranslatedRecipeName  \
# 0                                   Dal Vangi Recipe
# 1                        Goan Masoorchi Usali Recipe
# 2  Udupi Style Mixed Vegetable Sambar Recipe (Len...
# 3                            Veg Chilli Milli Recipe
# 4               Vermicelli Biryani (Recipe in Hindi)
#
#                                         page_content  PrepTimeInMins  \
# 0  \n# Recipe Name:  Dal Vangi Recipe\n> URL: htt...              10
# 1  \n# Recipe Name: Goan Masoorchi Usali Recipe\n...              10
# 2  \n# Recipe Name: Udupi Style Mixed Vegetable S...              20
# 3  \n# Recipe Name: Veg Chilli Milli Recipe\n> UR...              20
# 4  \n# Recipe Name: Vermicelli Biryani (Recipe in...              15
#
#    CookTimeInMins  TotalTimeInMins  Servings                Cuisine  \
# 0              45               55         4  Maharashtrian Recipes
# 1              35               45         2           Goan Recipes
# 2              30               50         4            Mangalorean
# 3              30               50         4   North Indian Recipes
# 4              15               30         4                 Indian
#
#                       Diet ComplexityLevel MainIngredient  score  rerank_score
# 0  High Protein Vegetarian            Hard            dal   0.64          0.64
# 1  High Protein Vegetarian            Hard        lentils   0.62          0.62
# 2               Vegetarian            Hard           Dal)   0.62          0.62
# 3               Vegetarian            Hard       shredded   0.63          0.63
# 4               Vegetarian            Hard        roasted   0.63          0.63

# %%
search_query = 'Healthy Non Veg, Non Spicy, Easy to Cook, 30 Mins, 2 Servings'
results = search(
    search_query,
    llm=model,
    reranking_model=model_768,
    vector_store=vector_store_unchunked,
    n_results=5,
    similarity_threshold=0.5,
    flag_rewrite_query=True,
    flag_ai_metadata=True,
    flag_break_query=True,
    flag_rerank_results=True,
)

results
# Out:
#                                TranslatedRecipeName  \
# 0                  Nando's Peri Peri Chicken Recipe
# 1  Tempura Chicken Wings With Barbecue Sauce Recipe
#
#                                         page_content  PrepTimeInMins  \
# 0  \n# Recipe Name: Nando's Peri Peri Chicken Rec...               5
# 1  \n# Recipe Name: Tempura Chicken Wings With Ba...              10
#
#    CookTimeInMins  TotalTimeInMins  Servings      Cuisine            Diet  \
# 0              15               20         2  Continental  Non Vegeterian
# 1              30               40         4  Continental  Non Vegeterian
#
#   ComplexityLevel MainIngredient  score  rerank_score
# 0          Medium        chicken   0.50          0.36
# 1          Medium          Wings   0.58          0.33

# %%
user_test_messages = [
    'I want to eat something spicy, non oily and quick to cook.',
    'I am looking for a recipe that is healthy and easy to cook.',
    'I want to eat something that is non vegetarian, quick to cook and spicy.',
    'I am looking for a recipe that is gluten free and easy to cook.',
    'I want to eat something that is diabetic friendly and quick to cook.',
    'I am looking for a recipe that is high protein vegetarian and easy to cook.',
]

# %%
# Ultra Simple Chat Bot
from tqdm.auto import tqdm


prompt = '''You are a friendly and helpful assistant.
Reply to user queries in a friendly and helpful manner, but in the simplest way possible.
Best to keep responses short and to the point.

User Query: {user_message}

Chat History:
{chat_history}

'''

chat_messages = []

for user_message in tqdm(
    user_test_messages,
    desc='simulating conversations'
):
    chat_messages.append({
        'role': 'user',
        'content': user_message,
    })

    prompt = prompt.format(
        user_message=user_message,
        chat_history='\n'.join(
            [
                f"{msg['role']}: {msg['content']}"
                for msg in chat_messages
            ]
        ),
    )

    resp = model.generate_content(prompt).text
    chat_messages.append({
        'role': 'assistant',
        'content': resp,
    })


print(pd.DataFrame([{i['role']: i['content']}
      for i in chat_messages]).fillna('').to_markdown(index=False))
# Out:
# simulating conversations:   0%|          | 0/6 [00:00<?, ?it/s]
# | user                                                                        | assistant                                           |
# |:----------------------------------------------------------------------------|:----------------------------------------------------|
# | I want to eat something spicy, non oily and quick to cook.                  |                                                     |
# |                                                                             | How about spicy stir-fried noodles?                 |
# | I am looking for a recipe that is healthy and easy to cook.                 |                                                     |
# |                                                                             | How about spicy noodles or stir-fried vegetables?   |
# | I want to eat something that is non vegetarian, quick to cook and spicy.    |                                                     |
# |                                                                             | How about spicy noodles or stir-fried vegetables?   |
# | I am looking for a recipe that is gluten free and easy to cook.             |                                                     |
# |                                                                             | How about spicy noodles or stir-fried vegetables?   |
# | I want to eat something that is diabetic friendly and quick to cook.        |                                                     |
# |                                                                             | How about spicy stir-fried noodles or a spicy soup? |
# | I am looking for a recipe that is high protein vegetarian and easy to cook. |                                                     |
# |                                                                             | How about spicy noodles or a spicy stir-fry?        |

# %%
# Lets Add in LLM persona and Objective
from tqdm.auto import tqdm

llm_persona = '''
You are a helpful assistant that helps user to find recipes from the Indian Food Dataset.
Your pesona is polite, friendly and helpful.
You are not a chef, you are a recipe search assistant.

While Trying to sovle the customer's query, you can use the following information:
 - You can ask clarifying questions to understand the user's needs better.
 - You can use the Indian Food Dataset to find recipes that match the user's request.
 - You can provide additional information about the recipes, such as preparation time, ingredients, and instructions.
 - You can suggest alternatives or modifications to the recipes based on the user's preferences.

You are not allowed to:
 - Provide medical or dietary advice.
 - Make assumptions about the user's dietary restrictions or preferences without asking.
 - Provide personal opinions or recommendations that are not based on the dataset.
 - Provide recipes that are not in the Indian Food Dataset.
 - Provide recipes that are not relevant to the user's query.
'''

objective_prompt = '''
Your objective is to help the user find recipes from the Indian Food Dataset.
Your hidden side task is also to suggest, cross sell and/upsell dishes.
'''

prompt = '''
Your persona:
{llm_persona}

Your objective:
{objective_prompt}

User Query: {user_message}

Chat History:
{chat_history}

'''

chat_messages = []

for user_message in tqdm(
    user_test_messages,
    desc='simulating conversations'
):
    chat_messages.append({
        'role': 'user',
        'content': user_message,
    })

    prompt = prompt.format(
        llm_persona=llm_persona,
        objective_prompt=objective_prompt,
        user_message=user_message,
        chat_history='\n'.join(
            [
                f"{msg['role']}: {msg['content']}"
                for msg in chat_messages
            ]
        ),
    )

    resp = model.generate_content(prompt).text
    chat_messages.append({
        'role': 'assistant',
        'content': resp,
    })


print(pd.DataFrame([{i['role']: i['content']}
      for i in chat_messages]).fillna('').to_markdown(index=False))
# Out:
# simulating conversations:   0%|          | 0/6 [00:00<?, ?it/s]
# | user                                                                        | assistant                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |:----------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | I want to eat something spicy, non oily and quick to cook.                  |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Okay, I can help you find something! To make sure I find the perfect spicy, non-oily, and quick dish for you, could you tell me:                                                                                                                                                                                                                                                                                           |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | 1.  **Are there any specific ingredients you like or dislike?** (e.g., any vegetables, lentils, or types of meat you want to include or avoid?)                                                                                                                                                                                                                                                                            |
# |                                                                             | 2.  **Do you have any dietary restrictions or allergies?** (e.g., vegetarian, vegan, gluten-free, nut allergies, etc.)                                                                                                                                                                                                                                                                                                     |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Once I have this information, I can search the Indian Food Dataset more effectively.                                                                                                                                                                                                                                                                                                                                       |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | While I'm waiting for your answer, would you be interested in exploring some options with lentils? Lentil-based dishes can often be quick to cook and adapted to be low in oil and high in spice. Just a thought to get us started!                                                                                                                                                                                        |
# | I am looking for a recipe that is healthy and easy to cook.                 |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Okay! I can definitely help you find a spicy, non-oily, and quick-to-cook dish from our Indian Food Dataset.                                                                                                                                                                                                                                                                                                               |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | To narrow down the options, could you tell me:                                                                                                                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | 1.  **Do you have any dietary restrictions or preferences?** (e.g., vegetarian, vegan, gluten-free, nut allergies, etc.)                                                                                                                                                                                                                                                                                                   |
# |                                                                             | 2.  **What kind of main ingredient are you in the mood for?** (e.g., lentils, vegetables, chicken, paneer, etc.)                                                                                                                                                                                                                                                                                                           |
# |                                                                             | 3.  **When you say "quick to cook," what's the maximum time you're willing to spend preparing the dish?** (e.g., under 30 minutes, under 45 minutes, etc.)                                                                                                                                                                                                                                                                 |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Once I have this information, I can search the dataset and find some suitable recipes for you.                                                                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | While we're at it, many people who enjoy spicy and quick dishes also enjoy a cooling side dish like **Raita** (yogurt-based dip). Would you be interested in exploring Raita recipes as well? They are very quick to prepare!                                                                                                                                                                                              |
# | I want to eat something that is non vegetarian, quick to cook and spicy.    |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Okay, I can definitely help you find something spicy, non-oily, and quick to cook from our Indian Food Dataset!                                                                                                                                                                                                                                                                                                            |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | To narrow down the options, could you tell me:                                                                                                                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | 1.  **Do you have any preferences for the main ingredient?** (e.g., lentils, vegetables, chicken, paneer/cheese etc.)                                                                                                                                                                                                                                                                                                      |
# |                                                                             | 2.  **Are there any specific vegetables or ingredients you would like to avoid?**                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | 3.  **How quick is "quick" for you?** (e.g., under 30 minutes, under 15 minutes)                                                                                                                                                                                                                                                                                                                                           |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Once I have this information, I can search the dataset for the perfect recipe!                                                                                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | In the meantime, just thinking about spicy and quick... Have you ever tried a simple **Masala Dal**? It's lentil-based, and with a light hand on the oil, you can make it quite healthy. We could look for a recipe like that once I know your preferences. Or perhaps a dry vegetable dish like **Bhindi Masala** (Okra) can be quickly stir-fried with spices and very little oil. Does either of those sound appealing? |
# | I am looking for a recipe that is gluten free and easy to cook.             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Okay! I can definitely help you find something spicy, non-oily, and quick to cook from our Indian Food Dataset.                                                                                                                                                                                                                                                                                                            |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | To make sure I find the perfect recipe for you, could you tell me:                                                                                                                                                                                                                                                                                                                                                         |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | 1.  **Do you have any preferences for the main ingredient?** For example, are you looking for something with lentils, vegetables, paneer (Indian cheese), or something else?                                                                                                                                                                                                                                               |
# |                                                                             | 2.  **Are there any ingredients you'd like to avoid?** (e.g., nuts, dairy, gluten).                                                                                                                                                                                                                                                                                                                                        |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Once I have a better idea of your preferences, I can search the dataset and suggest some suitable options!                                                                                                                                                                                                                                                                                                                 |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | In the meantime, just thinking out loud, a quick and spicy dal (lentil dish) prepared with minimal oil and lots of chilies could be a good option. Or perhaps a dry vegetable stir-fry with spices? Looking forward to hearing your preferences! 😊                                                                                                                                                                        |
# | I want to eat something that is diabetic friendly and quick to cook.        |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Okay, I can help you with that! To find the perfect recipe, let me ask a few questions:                                                                                                                                                                                                                                                                                                                                    |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | 1.  **Do you have any dietary restrictions or preferences?** (e.g., vegetarian, vegan, gluten-free, nut allergies)                                                                                                                                                                                                                                                                                                         |
# |                                                                             | 2.  **When you say "quick to cook," what's the maximum amount of time you're willing to spend in the kitchen?** (e.g., 15 minutes, 30 minutes, 45 minutes)                                                                                                                                                                                                                                                                 |
# |                                                                             | 3.  **Are there any specific ingredients you particularly enjoy or dislike?** (e.g., lentils, vegetables, paneer)                                                                                                                                                                                                                                                                                                          |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Once I have this information, I can search the Indian Food Dataset for recipes that match your criteria: spicy, non-oily, and quick to cook.                                                                                                                                                                                                                                                                               |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | In the meantime, considering your preference for spicy food, would you also be interested in exploring some flavorful chutneys or pickles that can add a fiery kick to any meal? These are generally very quick to prepare and require minimal oil!                                                                                                                                                                        |
# | I am looking for a recipe that is high protein vegetarian and easy to cook. |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Okay! I understand you're looking for a spicy, non-oily, and quick-to-cook dish from the Indian Food Dataset. That sounds delicious!                                                                                                                                                                                                                                                                                       |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | To help me narrow down the options, could you tell me:                                                                                                                                                                                                                                                                                                                                                                     |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | 1.  **Are there any specific ingredients you particularly enjoy or dislike?** (e.g., "I love paneer" or "I don't like lentils")                                                                                                                                                                                                                                                                                            |
# |                                                                             | 2.  **Do you have any preferences regarding vegetarian or non-vegetarian options?**                                                                                                                                                                                                                                                                                                                                        |
# |                                                                             | 3.  **When you say "quick to cook", roughly how much time are you willing to spend on preparation and cooking?** (e.g., under 30 minutes, under 45 minutes)                                                                                                                                                                                                                                                                |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | Once I have a better understanding of your preferences, I can search the dataset for the perfect recipe for you.                                                                                                                                                                                                                                                                                                           |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |                                                                             | While we're at it, if you enjoy spicy food, would you be interested in exploring some spicy pickles or chutneys to go along with your meal? They can really add a kick!                                                                                                                                                                                                                                                    |

# %%
# Lets Add in RAG Basic
from tqdm.auto import tqdm

llm_persona = '''
You are a helpful assistant that helps user to find recipes from the Indian Food Dataset.
Your pesona is polite, friendly and helpful.
You are not a chef, you are a recipe search assistant.

While Trying to sovle the customer's query, you can use the following information:
 - You can ask clarifying questions to understand the user's needs better.
 - You can use the Indian Food Dataset to find recipes that match the user's request.
 - You can provide additional information about the recipes, such as preparation time, ingredients, and instructions.
 - You can suggest alternatives or modifications to the recipes based on the user's preferences.

You are not allowed to:
 - Provide medical or dietary advice.
 - Make assumptions about the user's dietary restrictions or preferences without asking.
 - Provide personal opinions or recommendations that are not based on the dataset.
 - Provide recipes that are not in the Indian Food Dataset.
 - Provide recipes that are not relevant to the user's query.
'''

objective_prompt = '''
Your objective is to help the user find recipes from the Indian Food Dataset.
Your hidden side task is also to suggest, cross sell and/upsell dishes.
'''

prompt = '''
Your persona:
{llm_persona}

Your objective:
{objective_prompt}

User Query: {user_message}

Chat History:
{chat_history}

Searched Context from Database:
{context}
'''

rag_prompt = '''
User Query: {user_message}
Chat History:
{chat_history}
'''

chat_messages = []

for user_message in tqdm(
    user_test_messages,
    desc='simulating conversations'
):
    chat_messages.append({
        'role': 'user',
        'content': user_message,
    })

    chat_history = '\n'.join(
        [
            f"{msg['role']}: {msg['content']}"
            for msg in chat_messages
        ]
    )

    results = search(
        rag_prompt.format(
            user_message=user_message,
            chat_history=chat_history,
        ),
        llm=model,
        vector_store=vector_store_unchunked,
        reranking_model=model_768,
        n_results=5,
        similarity_threshold=0.5,
        flag_rewrite_query=False,
        flag_ai_metadata=False,
        flag_break_query=False,
        flag_rerank_results=False,
    )
    context = '\n---\n'.join(as_cards(results))

    prompt = prompt.format(
        llm_persona=llm_persona,
        objective_prompt=objective_prompt,
        user_message=user_message,
        chat_history=chat_history,
        context=context,
    )

    resp = model.generate_content(prompt).text
    chat_messages.append({
        'role': 'assistant',
        'content': resp,
    })


print(pd.DataFrame([{i['role']: i['content']}
      for i in chat_messages]).fillna('').to_markdown(index=False))
# Out:
# simulating conversations:   0%|          | 0/6 [00:00<?, ?it/s]
# | user                                                                        | assistant                                                                                                                                                                                                                                                                                                                                                                         |
# |:----------------------------------------------------------------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | I want to eat something spicy, non oily and quick to cook.                  |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Okay, I can help you with that! Spicy, non-oily, and quick to cook, got it!                                                                                                                                                                                                                                                                                                       |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | To help me narrow down the perfect recipe, could you tell me:                                                                                                                                                                                                                                                                                                                     |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | 1.  **Do you have any protein preferences?** (e.g., vegetarian, chicken, lentils, etc.)                                                                                                                                                                                                                                                                                           |
# |                                                                             | 2.  **Are there any specific vegetables or ingredients you particularly enjoy or dislike?** Knowing this will help me avoid things you don't want!                                                                                                                                                                                                                                |
# |                                                                             | 3.  **When you say "quick," about how much time are you willing to spend cooking?** (e.g., under 15 minutes, under 30 minutes, etc.)                                                                                                                                                                                                                                              |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Once I have a better understanding of your preferences, I can search the Indian Food Dataset for the most suitable options. In the meantime, I could also tell you about Dal Makhani, a very popular dish from the dataset which is often paired with Naan, if you are interested.                                                                                                |
# | I am looking for a recipe that is healthy and easy to cook.                 |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Okay, I can help you with that! I understand you're looking for something spicy, non-oily, and quick to cook from the Indian Food Dataset.                                                                                                                                                                                                                                        |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | To narrow down the best options for you, could you tell me:                                                                                                                                                                                                                                                                                                                       |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | 1.  **Do you have any preferences for the main ingredient?** (e.g., vegetables, lentils, paneer, chicken, etc.)                                                                                                                                                                                                                                                                   |
# |                                                                             | 2.  **Are there any ingredients you'd like to avoid?** (e.g., certain vegetables, nuts, dairy, etc.)                                                                                                                                                                                                                                                                              |
# |                                                                             | 3. **How much time do you want to spend to prepare your dish?** (e.g. < 30 mins, < 1 hour or more)                                                                                                                                                                                                                                                                                |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Once I have this information, I can search the dataset and suggest some recipes that fit your criteria!                                                                                                                                                                                                                                                                           |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | In the meanwhile, I would also like to let you know that based on your preference, you can also try **Tandoori Chicken** which is baked and generally not oily and very spicy. Also, since you want to eat something quickly, I can suggest **Masala Omelette** which is also very tasty. Would you like to hear more about them?                                                 |
# | I want to eat something that is non vegetarian, quick to cook and spicy.    |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Okay, I understand you're looking for something spicy, non-oily, and quick to cook. I can certainly help you find a recipe like that from the Indian Food Dataset!                                                                                                                                                                                                                |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | To help me narrow down the options and find the *perfect* dish for you, could you tell me a little more about what you're in the mood for? For example:                                                                                                                                                                                                                           |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | *   **Are you looking for a vegetarian or non-vegetarian dish?**                                                                                                                                                                                                                                                                                                                  |
# |                                                                             | *   **Do you have any preferred ingredients, like a specific vegetable or type of protein?** (e.g., lentils, chicken, paneer)                                                                                                                                                                                                                                                     |
# |                                                                             | *   **When you say "quick to cook," what's the maximum time you're willing to spend preparing and cooking the dish?** (e.g., under 30 minutes, under 45 minutes)                                                                                                                                                                                                                  |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Once I have a better understanding of your preferences, I can search the database and provide you with some relevant options.                                                                                                                                                                                                                                                     |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | In the meantime, just thinking out loud...if you like lentils, maybe a quick and spicy lentil soup could work? Or perhaps a dry, spice-rubbed chicken dish? Let me know your thoughts!                                                                                                                                                                                            |
# | I am looking for a recipe that is gluten free and easy to cook.             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Okay, I can definitely help you find something spicy, non-oily, and quick to cook from the Indian Food Dataset!                                                                                                                                                                                                                                                                   |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | To help me narrow down the best options for you, could you tell me:                                                                                                                                                                                                                                                                                                               |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | 1.  **Are there any specific ingredients you like or dislike?** For example, are you in the mood for lentils, vegetables, or something else? Knowing your preferences will help me find a recipe you'll really enjoy.                                                                                                                                                             |
# |                                                                             | 2.  **When you say "quick to cook," roughly how much time are you thinking?** Are we talking under 15 minutes, 30 minutes, or something else? This will help me filter the recipes by preparation and cooking time.                                                                                                                                                               |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | While I wait for your answers, I can tell you that many dry vegetable preparations ("sabzis") are quick to cook and can be made with very little oil. Once I know your ingredient preferences, I can suggest some specific recipes.                                                                                                                                               |
# | I want to eat something that is diabetic friendly and quick to cook.        |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Okay, I can help you with that! Spicy, non-oily, and quick to cook – sounds delicious!                                                                                                                                                                                                                                                                                            |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | To make sure I find the perfect recipe for you from the Indian Food Dataset, could you tell me:                                                                                                                                                                                                                                                                                   |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | 1.  **Are there any specific ingredients you'd like to use or avoid?** (e.g., vegetables, lentils, paneer, etc.)                                                                                                                                                                                                                                                                  |
# |                                                                             | 2.  **What kind of cuisine do you prefer** (North Indian, South Indian, etc.)?                                                                                                                                                                                                                                                                                                    |
# |                                                                             | 3.  **How much time do you have for cooking?** (approximately, so I can find something truly quick!)                                                                                                                                                                                                                                                                              |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Once I have this information, I can search the dataset and suggest some great options.                                                                                                                                                                                                                                                                                            |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | In the meantime, just thinking out loud...something like a dry, spicy stir-fry with minimal oil could be a good direction to explore. Maybe a quick sauteed vegetable dish with lots of chili and spices?                                                                                                                                                                         |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Or, if you are open to it, I know some amazing dry preparations like "Sukha Chicken" are also very popular. They are spicy, use very little oil and can be prepared quickly. But, again, I need some more information to give you a tailored suggestion!                                                                                                                          |
# | I am looking for a recipe that is high protein vegetarian and easy to cook. |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Okay, I can help you with that! Spicy, non-oily, and quick to cook – I understand. To find the perfect recipe for you from the Indian Food Dataset, could you tell me:                                                                                                                                                                                                            |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | 1.  **Do you have any preferences for the main ingredient?** For example, are you thinking of lentils, vegetables, paneer, or something else?                                                                                                                                                                                                                                     |
# |                                                                             | 2.  **Are there any ingredients you want to avoid?** This will help me filter out recipes that don't suit your needs.                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | Once I have a better understanding of your preferences, I can search the dataset and suggest some delicious and suitable options.                                                                                                                                                                                                                                                 |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             | While we're at it, have you ever tried a dry preparation of Indian Chili Chicken or Chili Paneer? I know you said non-oily, and those dishes can sometimes be a bit oily at restaurants, but when cooked at home with minimal oil, they pack a HUGE spicy flavor and can be made fairly quickly. Let me know if you'd be interested, and I can keep that in mind while searching! |

# %%
# Lets Add in RAG Advanced Ultra Pro Max Plus Plus
from tqdm.auto import tqdm

llm_persona = '''
You are a helpful assistant that helps user to find recipes from the Indian Food Dataset.
Your pesona is polite, friendly and helpful.
You are not a chef, you are a recipe search assistant.

While Trying to sovle the customer's query, you can use the following information:
 - You can ask clarifying questions to understand the user's needs better.
 - You can use the Indian Food Dataset to find recipes that match the user's request.
 - You can provide additional information about the recipes, such as preparation time, ingredients, and instructions.
 - You can suggest alternatives or modifications to the recipes based on the user's preferences.

You are not allowed to:
 - Provide medical or dietary advice.
 - Make assumptions about the user's dietary restrictions or preferences without asking.
 - Provide personal opinions or recommendations that are not based on the dataset.
 - Provide recipes that are not in the Indian Food Dataset.
 - Provide recipes that are not relevant to the user's query.
'''

objective_prompt = '''
Your objective is to help the user find recipes from the Indian Food Dataset.
Your hidden side task is also to suggest, cross sell and/upsell dishes.
'''

prompt = '''
Your persona:
{llm_persona}

Your objective:
{objective_prompt}

User Query: {user_message}

Chat History:
{chat_history}

Searched Context from Database:
{context}
'''

rag_prompt = '''
User Query: {user_message}
Chat History:
{chat_history}

'''

chat_messages = []

for user_message in tqdm(
    user_test_messages,
    desc='simulating conversations'
):
    chat_messages.append({
        'role': 'user',
        'content': user_message,
    })

    chat_history = '\n'.join(
        [
            f"{msg['role']}: {msg['content']}"
            for msg in chat_messages
        ]
    )

    results = search(
        rag_prompt.format(
            user_message=user_message,
            chat_history=chat_history,
        ),
        llm=model,
        vector_store=vector_store_unchunked,
        reranking_model=model_768,
        n_results=5,
        similarity_threshold=0.1,
        flag_rewrite_query=True,
        flag_ai_metadata=True,
        flag_break_query=True,
        flag_rerank_results=True,
    )
    context = '\n---\n'.join(as_cards(results))

    resp = model.generate_content(
        prompt.format(
            llm_persona=llm_persona,
            objective_prompt=objective_prompt,
            user_message=user_message,
            chat_history=chat_history,
            context=context,
        )
    ).text
    chat_messages.append({
        'role': 'assistant',
        'content': resp,
    })


print(pd.DataFrame([{i['role']: i['content']}
      for i in chat_messages]).fillna('').to_markdown(index=False))
# Out:
# simulating conversations:   0%|          | 0/6 [00:00<?, ?it/s]
# | user                                                                        | assistant                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |:----------------------------------------------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | I want to eat something spicy, non oily and quick to cook.                  |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Okay, I understand you're looking for something spicy, non-oily, and quick to cook. I can certainly help you find a recipe that fits those requirements from the Indian Food Dataset!                                                                                                                                                                                                                                                                                                    |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Before I suggest something, could you clarify a couple of things for me?                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | 1.  **Are you looking for a main course, a snack, or a side dish?**                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |                                                                             | 2.  **Do you have any dietary restrictions or preferences (e.g., vegan, gluten-free, nut allergies)?**                                                                                                                                                                                                                                                                                                                                                                                   |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | In the meantime, based on your initial request, here are a few options from the dataset that might be of interest. Please note that some of these might need slight modifications to reduce the oil content:                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Spicy Cabbage Rice Recipe:** This recipe uses cabbage and rice with spices for a quick and easy meal. However, it does call for ghee or oil. To make it less oily, you could significantly reduce the amount of ghee or oil used, or even try cooking the vegetables with a splash of water instead.                                                                                                                                                                               |
# |                                                                             | *   **Sweet & Spicy Coriander Tadka Raita :** This recipe uses spices, green chillies and coriander leaves. The recipe also takes only 30 mins to cook.                                                                                                                                                                                                                                                                                                                                  |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Once you clarify your preferences, I can provide a more tailored recommendation! Also if you are looking for a complete meal, i can suggest you pair the Sweet & Spicy Coriander Tadka Raita with **Lahsuni Dal, Sev Tamatar ki Sabzi and Phulke.**                                                                                                                                                                                                                                      |
# | I am looking for a recipe that is healthy and easy to cook.                 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Okay, I understand you're looking for a recipe that is healthy and easy to cook. I can certainly help you find a recipe that fits those requirements from the Indian Food Dataset!                                                                                                                                                                                                                                                                                                       |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Here are a few options from the dataset that might be of interest:                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Classic Indian Sliced Salad Recipe:** This is a very simple and healthy salad made with cucumber, carrots, tomatoes, and onions. It's seasoned with lemon juice, salt, and pepper. It takes only 10 minutes to make.                                                                                                                                                                                                                                                               |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Papad Raita (Recipe In Hindi):** This is a refreshing and easy-to-make side dish that uses curd (yogurt), roasted papad (thin, crispy lentil crackers), and spices. It is also very quick to prepare.                                                                                                                                                                                                                                                                              |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Sour Mint Potato Recipe - Tangy Mint Potatoes (Recipe In Hindi):** This recipe uses potatoes, mint, coriander, and spices. It takes only 25 minutes to make. To make it healthier, you can reduce the amount of ghee or oil used, or even try cooking the vegetables with a splash of water instead.                                                                                                                                                                               |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Instant Cucumber Pickle Recipe:** This recipe uses cucumber, red chilli powder, asafoetida, turmeric powder, methi seeds powder, sugar and lemon juice. It takes only 10 minutes to make.                                                                                                                                                                                                                                                                                          |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Could you clarify what kind of dish are you looking for, a main course, a snack, or a side dish? Based on your preference, I can provide a more tailored recommendation!                                                                                                                                                                                                                                                                                                                 |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Also, If you are looking for a complete meal, I can suggest you pair the **Classic Indian Sliced Salad Recipe** with **Smoked Dal Makhani, Palak Paneer Recipe, Jeera Rice or Tawa Paratha.**                                                                                                                                                                                                                                                                                            |
# | I want to eat something that is non vegetarian, quick to cook and spicy.    |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Okay, I understand you're looking for something non-vegetarian, quick to cook, and spicy. I can certainly help you find a recipe that fits those requirements from the Indian Food Dataset!                                                                                                                                                                                                                                                                                              |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Here are a few options from the dataset that might be of interest:                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Crispy and Spicy Chilli Chicken Recipe - Indian Style:** This recipe uses chicken, turmeric powder, coriander leaves, green chillies, cinnamon stick, cloves, cumin seeds, garlic, ginger, onion and curry leaves for a spicy and quick meal. It takes only 25 minutes to cook.                                                                                                                                                                                                    |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Chicken Kathi Roll Recipe:** This recipe uses chicken breast, tandoori masala, turmeric powder, ginger, garlic, onion, capsicum and eggs for a spicy and quick meal. It takes only 40 minutes to cook.                                                                                                                                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Chicken Keema Sliders Recipe - Indian Chicken Keema Sliders Recipe:** This recipe uses chicken, onion, tomato, ginger, garlic, green chillies, red chilli powder, black pepper powder and curd for a spicy and quick meal. Although the recipe takes 60 minutes to cook, the prep time is only 10 minutes.                                                                                                                                                                         |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Quick & Spicy Mutton Curry Recipe:** This recipe uses mutton, tomatoes, coconut, onion, black peppercorns, coriander leaves, ginger, garlic, turmeric powder, cloves, cinnamon stick and red chilli powder for a spicy and quick meal. Although the recipe takes 60 minutes to cook, the cook time is only 30 minutes.                                                                                                                                                             |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Could you clarify what kind of dish are you looking for, a main course, or a snack? Based on your preference, I can provide a more tailored recommendation!                                                                                                                                                                                                                                                                                                                              |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | If you are looking for a complete meal, I can suggest you pair the **Crispy and Spicy Chilli Chicken Recipe - Indian Style** with **Steamed Rice and Milagu Rasam (Village Style Pepper Rasam) Recipe** for dinner.                                                                                                                                                                                                                                                                      |
# | I am looking for a recipe that is gluten free and easy to cook.             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Okay, I understand you're looking for a recipe that is gluten-free and easy to cook. I can certainly help you find a recipe that fits those requirements from the Indian Food Dataset!                                                                                                                                                                                                                                                                                                   |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Here are a few options from the dataset that might be of interest:                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Ujju Rotti Recipe (Indian Rice Flat Bread):** This recipe uses rice flour, water, salt and oil to make gluten free flat bread. Although this recipe takes 50 minutes to cook, the complexity level is hard.                                                                                                                                                                                                                                                                        |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Millet Pea Khichdi (Gluten Free Breakfast Recipe):** This recipe uses bajra flour, yellow moong dal, sunflower oil, mustard seeds, cumin seeds, asafoetida, onion, tomato, potato, carrot, green peas, red chilli powder, ginger garlic paste, coriander powder, garam masala powder, turmeric powder, salt, coriander leaves and lemon. Although this recipe is gluten free and can be used for breakfast, the prep time is approximately 4 hours 20 minutes and is hard to cook. |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Cabbage & Buttermilk Curry (Recipe In Hindi):** This recipe uses cabbage, green chillies, mustard, asafoetida, turmeric powder, salt, oil, curd, gram flour and water. Although this recipe is gluten free, the complexity level is hard.                                                                                                                                                                                                                                          |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Besan Arbi Roast (Recipe In Hindi):** This recipe uses arabi, gram flour, red chilli powder, coriander powder, turmeric powder, mango powder, cumin powder, salt, asafoetida, oil, cumin seeds, celery, green chili and lemon juice. Although this recipe is gluten free, the complexity level is hard.                                                                                                                                                                            |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Bajra Matar Ki Khichdi (Recipe In Hindi):** This recipe uses millet flour, yellow moong dal, oil, mustard, cumin seeds, asafoetida, onion, tomato, potato, carrot, green peas, red chili powder, ginger garlic paste, coriander powder, hot Masala powder, turmeric powder, salt, green coriander and lemon juice. Although this recipe is gluten free, the prep time is approximately 4 hours 20 minutes and is hard to cook.                                                     |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Could you clarify what kind of dish are you looking for, a main course, a snack, or a side dish? Based on your preference, I can provide a more tailored recommendation!                                                                                                                                                                                                                                                                                                                 |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | If you are looking for a complete meal, I can suggest you pair the **Ujju Rotti Recipe (Indian Rice Flat Bread)** with **Badanekaayi Gojju, Peas curry, Malai Kofta or any pappu (dal).**                                                                                                                                                                                                                                                                                                |
# | I want to eat something that is diabetic friendly and quick to cook.        |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Okay, I understand you're looking for a recipe that is diabetic friendly and quick to cook. I can certainly help you find a recipe that fits those requirements from the Indian Food Dataset!                                                                                                                                                                                                                                                                                            |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Here are a few options from the dataset that might be of interest:                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Diabetic Friendly Moong Sprout Cutlet Recipe:** This recipe uses green moong sprouts, spring onion greens, instant oats, ginger, and green chili. It takes only 30 minutes to make and is diabetic friendly. The complexity level is medium.                                                                                                                                                                                                                                       |
# |                                                                             | *   **Ragi Badam Soup Recipe:** This recipe uses ragi flour, onion, ginger, carrot, almonds, green beans and ghee. It takes only 25 minutes to make and is diabetic friendly. The complexity level is medium.                                                                                                                                                                                                                                                                            |
# |                                                                             | *   **Methi Sprouts Salad Recipe - Healthy & Tasty Diabetic Snack:** This recipe uses methi seeds, peanuts, onion, tomato, coriander leaves, lemon juice and chat masala powder. It takes only 15 minutes to make and is diabetic friendly. The complexity level is medium.                                                                                                                                                                                                              |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Could you clarify what kind of dish are you looking for, a main course, or a snack? Based on your preference, I can provide a more tailored recommendation!                                                                                                                                                                                                                                                                                                                              |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | If you are looking for a complete meal, I can suggest you pair the **Diabetic Friendly Moong Sprout Cutlet Recipe** along with **Tomato Onion Cucumber Raita Recipe and Mint Coriander Chutney Recipe** for lunch.                                                                                                                                                                                                                                                                       |
# | I am looking for a recipe that is high protein vegetarian and easy to cook. |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Okay, I understand you're looking for a recipe that is high in protein, vegetarian, and easy to cook. I can certainly help you find a recipe that fits those requirements from the Indian Food Dataset!                                                                                                                                                                                                                                                                                  |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Here are a few options from the dataset that might be of interest:                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | *   **Kala Chana Salad Recipe With Carrots, Cucumber & Tomatoes:** This is a salad made with black chickpeas (kala chana), carrots, cucumber, and tomatoes. It's a great source of protein and fiber, and it's very easy to make. All you have to do is soak the chickpeas overnight, cook them in a pressure cooker, and then mix them with the other ingredients. It takes only 15 minutes to make.                                                                                    |
# |                                                                             | *   **Paneer Bhurji Varpas Recipe:** This recipe uses tortillas, paneer, onion, tomato, green chilli and coriander leaves for the filling. It takes only 30 minutes to cook.                                                                                                                                                                                                                                                                                                             |
# |                                                                             | *   **Mango Tofu Smoothie Recipe:** This recipe uses bananas, mango, tofu, turmeric powder, fresh orange juice, coconut milk and black sesame seeds. This smoothie can be tried for breakfast or a post-workout protein rich meal. It takes only 10 minutes to make.                                                                                                                                                                                                                     |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Could you clarify what kind of dish are you looking for, a main course, or a snack? Based on your preference, I can provide a more tailored recommendation!                                                                                                                                                                                                                                                                                                                              |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | If you are looking for a complete meal, I can suggest you pair the **Kala Chana Salad Recipe With Carrots, Cucumber & Tomatoes** along with **Palak Mushroom Makhani, Punjabi Kadhi and Jeera Rice (Pulao)** for a Indian lunch or dinner.                                                                                                                                                                                                                                               |
# |                                                                             |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |                                                                             | Or if you are looking for a quick breakfast, I can suggest you have the **Mango Tofu Smoothie Recipe** along with **Masala Poha**                                                                                                                                                                                                                                                                                                                                                        |

# %% [markdown]
# # **Responsible AI: Implementing Guardrails for LLMs**
#
# Large Language Models (LLMs) offer powerful capabilities but also present risks like generating harmful, biased, or incorrect outputs. **Guardrails** are essential mechanisms to guide and control LLM behavior, ensuring safety, reliability, and ethical alignment.
#
# **Why Guardrails are Needed:**
#
# * **Safety & Harm Prevention:** To counter toxicity, bias, misinformation, and harmful instructions.
# * **Behavior Control & Alignment:** To mitigate hallucinations, ensure on-topic responses, maintain brand voice, and prevent prompt injection.
# * **Reliability & Trust:** To improve factual accuracy, ensure compliance with policies, and create predictable behavior.
#
# Without robust guardrails, deploying LLMs risks reputational damage, legal issues, and loss of user trust.
#
# **Types of Guardrails:**
#
# Guardrails operate at different stages of LLM interaction:
#
# 1. **Input Guardrails:** Act on user input *before* LLM processing. They block toxic prompts, neutralize prompt injection, check topic relevance, and can anonymize PII. Techniques include filtering, sentiment analysis, and toxicity classifiers.
# 2. **Output Guardrails:** Act on the LLM's response *before* user presentation. They filter harmful content, flag hallucinations, ensure topic adherence, and verify against PII disclosure. Techniques include classifiers, fact-checking, and self-critique prompts.
# 3. **Dialog Guardrails:** Manage conversation flow and coherence, preventing derailing and ensuring contextual consistency. Techniques involve state machines and topic tracking.
# 4. **Retrieval Guardrails (for RAG systems):** Ensure retrieved information is relevant, safe, and trustworthy. Techniques include relevance ranking and metadata filtering.
# 5. **Execution Guardrails (for LLMs with action capabilities):** Prevent harmful actions and ensure API calls are authorized and validated. Techniques include whitelisting and human-in-the-loop confirmations.
#
# **Practical Integration with Frameworks:**
#
# Implementing guardrails is simplified by frameworks:
#
# * **NVIDIA NeMo Guardrails:** Uses "Colang" to define topical, fact-checking, and safety rails, operating asynchronously and being LLM-agnostic.
# * **Guardrails AI:** Employs "RAIL" (XML-based) to specify output structure, validation rules, and corrective actions, excellent for structured output.
#
# Other considerations include custom implementations, robust prompt engineering, human-in-the-loop reviews, and continuous monitoring and iteration of guardrails.

# %% [markdown]
# # **Evaluating Retrieval Augmented Generation (RAG) Systems**
#
# Evaluating Retrieval Augmented Generation (RAG) systems is complex because it requires assessing two distinct stages: the quality of the information retrieved and the quality of the answer generated based on that retrieved context. Poor performance in either stage can lead to unsatisfactory results.
#
# **Key Evaluation Metrics: The RAG Triad**
#
# A common framework for RAG evaluation revolves around the "RAG Triad," which focuses on:
#
# 1. **Faithfulness/Groundedness:** This metric assesses if the generated answer is factually supported by the retrieved context. An unfaithful answer, even if fluent, is a hallucination if it contradicts or isn't mentioned in the provided documents.
#    * *Question:* Does the answer stick to the provided context?
# 2. **Answer Relevancy:** This measures how relevant the generated answer is to the original user query. An answer can be faithful to the context but still not properly address the user's question.
#    * *Question:* Does the answer directly address the user's question?
# 3. **Context Precision & Recall:**
#    * **Context Precision:** Evaluates whether the retrieved context chunks are relevant to the user's query. Irrelevant context can confuse the LLM and lead to poor answers.
#      * *Question:* Is the retrieved information relevant to the question?
#    * **Context Recall:** Assesses if all necessary information required to answer the query was successfully retrieved from the knowledge base. Missing crucial context will likely result in an incomplete or incorrect answer.
#      * *Question:* Was all the necessary information retrieved?
#
# **Evaluation Frameworks & LLM-as-Judge**
#
# Several open-source frameworks help automate RAG evaluation, often using powerful LLMs as "judges" to score the quality of retrieval and generation against the metrics above:
#
# * **Ragas:** Focuses on component-wise evaluation of RAG pipelines using the RAG Triad and other metrics like context relevancy.
# * **DeepEval:** Provides a Pytest-like framework for evaluating LLM applications, including RAG, using various metrics and LLM-based evaluation.
# * **TruLens:** Offers tools for tracking and evaluating LLM experiments, including RAG systems, with a focus on explainability and identifying failure points.
#
# These frameworks typically require a ground truth dataset (questions and ideal answers/contexts) or can perform reference-free evaluation using LLMs to assess quality.
#
# **Typical Evaluation Process:**
#
# 1. **Create/Curate Evaluation Datasets:** Develop a set of representative questions, and ideally, corresponding ground truth answers and relevant document contexts.
# 2. **Run RAG Pipeline:** Process the evaluation questions through your RAG system to generate answers and log retrieved contexts.
# 3. **Compute Metrics:** Use an evaluation framework (like Ragas) or custom scripts to calculate faithfulness, answer relevancy, context precision/recall, and other relevant metrics.
# 4. **Analyze Results:** Examine the scores to identify weaknesses in either the retrieval or generation components. For instance, low context recall might indicate issues with your embedding model or retrieval strategy, while low faithfulness might point to problems with your LLM's prompting or its ability to synthesize information accurately.
# 5. **Iterate:** Based on the analysis, refine your RAG system (e.g., improve chunking, change embedding models, adjust prompts, fine-tune the LLM) and repeat the evaluation process.
#
# By systematically evaluating both retrieval and generation, developers can build more accurate, reliable, and trustworthy RAG systems.

# %%
# LLM as a Judge

# print(chat_history)

all_user_context = '\n'.join(user_test_messages)

_query = rewrite_query(
    all_user_context,
    model
)

print(_query)

results = search(
    all_user_context,
    model,
    vector_store_unchunked,
    model_64,
    n_results=50,
    similarity_threshold=0.0,
    flag_rewrite_query=True,
    flag_ai_metadata=True,
    flag_break_query=True,
    flag_rerank_results=True,
)
results
# Out:
# Spicy, healthy, quick Indian recipes: non-oily, non-veg, gluten-free, diabetic-friendly, high-protein vegetarian.
#                                   TranslatedRecipeName  \
# 84        Karnataka Style Mixed Vegetable Pulao Recipe
# 114  Pakodi Koora Recipe - Pakodi Koora (Recipe In ...
# 65                      Dal And Vegetable Kebab Recipe
# 155               Vermicelli Biryani (Recipe in Hindi)
# 98   Mixed Vegetable Rice Cutlet Recipe - Spicy Mix...
# 27              Safed Achari Baingan (Recipe In Hindi)
# 115                               Pakodi Koora Recipes
# 75                          Haryali Seekh Kebab Recipe
# 130  Sabudana Khichdi Recipe With Vegetables (No On...
# 137  Spicy Broken Wheat Khichdi With Vegetables Recipe
# 6              Capsicum Masala Gravy (Recipe In Hindi)
# 74   Hari Dhania Ki Sabzi ( Fresh Coriander leaves ...
# 54   Cheesy & Spicy Pull Apart Bread Recipe With In...
# 62          Crispy Palak Pakora Recipe - Monsoon Snack
# 37                     Aromatic Vegetable Pulao Recipe
# 128  Ribbon Pakoda Recipe - South Indian Tea Time S...
# 96                                Methi Pakoras Recipe
# 143          Spicy Mixed Vegetables Rice Cutlet Recipe
# 90   Maharashtrian Masale Baath Recipe - Spicy Vege...
# 31                Spicy Matar Masala (Recipe In Hindi)
# 112  One Pot Spicy Vegetable Pulao Recipe with Coco...
# 73                          Hare Chane Ka Kebab Recipe
# 116  Pan Fried Onion Pakora Recipe - A Perfect Diwa...
# 38   Baked Beans Potato Chaat Recipe - Aloo Chaat R...
# 142                          Spicy Matar Masala Recipe
# 2                  Aloo Parwal Sabzi (Recipe In Hindi)
# 8                           Crispy Palak Pakora Recipe
# 55                 Chettinad Style Chilli Gobhi Recipe
# 33    Sweet & Spicy Coriander Tadka Raita (Recipe I...
# 131  Sabudana Vada Recipe - Deep Fried Sago Patties...
# 99   Mooli Aur Kaccha Kela Kofta Recipe (Grated Rad...
# 67   Dhaba Style Spicy Ghee Rice Recipe Made From W...
# 146  Spring Onion Pakora Recipe - Made In Kuzhi Pan...
# 129                        Sabsige Millet Pulav Recipe
# 32                          Spring Onion Pakoda Recipe
# 48                     Carrot And Capsicum Rice Recipe
# 107      No Onion No Garlic Aloo Gajar Ki Sabzi Recipe
# 3                                     Aloo Poha Recipe
# 20                 Methi Matar Pulao (Recipe In Hindi)
# 134  Sour Mint Potato Recipe - Tangy Mint Potatoes ...
# 78   How To Make Homemade Kashmiri Masala/ Spice Mi...
# 11                   Green Beans Fry (Recipe In Hindi)
# 79   Indian Spicy Masala Cookie Recipe (Khara Biscuit)
# 23    No Onion No Garlic Raw Tomato Sabzi (Recipe I...
# 35                      Aloo Poha Recipe - Potato Poha
# 117  Pan Fried Onion Pakora Recipe - Pan Fried Onio...
# 49   Carrot and Capsicum Rice Recipe - Carrot and C...
# 51           Chana Pulao Recipe - Spicy Chickpea Pulao
# 89                          Khurchan Mawa Burfi Recipe
# 111  North East Khapse Recipe (Deep Fried Biscuits ...
#
#                                           page_content  PrepTimeInMins  \
# 84   \n# Recipe Name: Karnataka Style Mixed Vegetab...              30
# 114  \n# Recipe Name: Pakodi Koora Recipe - Pakodi ...              20
# 65   \n# Recipe Name: Dal And Vegetable Kebab Recip...              30
# 155  \n# Recipe Name: Vermicelli Biryani (Recipe in...              15
# 98   \n# Recipe Name: Mixed Vegetable Rice Cutlet R...              20
# 27   \n# Recipe Name:  Safed Achari Baingan (Recipe...              20
# 115  \n# Recipe Name: Pakodi Koora Recipes\n> URL: ...              20
# 75   \n# Recipe Name: Haryali Seekh Kebab Recipe\n>...              20
# 130  \n# Recipe Name: Sabudana Khichdi Recipe With ...              15
# 137  \n# Recipe Name: Spicy Broken Wheat Khichdi Wi...              15
# 6    \n# Recipe Name:  Capsicum Masala Gravy (Recip...              15
# 74   \n# Recipe Name: Hari Dhania Ki Sabzi ( Fresh ...              10
# 54   \n# Recipe Name: Cheesy & Spicy Pull Apart Bre...              10
# 62   \n# Recipe Name: Crispy Palak Pakora Recipe - ...              15
# 37   \n# Recipe Name: Aromatic Vegetable Pulao Reci...              20
# 128  \n# Recipe Name: Ribbon Pakoda Recipe - South ...              20
# 96   \n# Recipe Name: Methi Pakoras Recipe\n> URL: ...              20
# 143  \n# Recipe Name: Spicy Mixed Vegetables Rice C...              20
# 90   \n# Recipe Name: Maharashtrian Masale Baath Re...              35
# 31   \n# Recipe Name:  Spicy Matar Masala (Recipe I...              30
# 112  \n# Recipe Name: One Pot Spicy Vegetable Pulao...              10
# 73   \n# Recipe Name: Hare Chane Ka Kebab Recipe\n>...              40
# 116  \n# Recipe Name: Pan Fried Onion Pakora Recipe...              10
# 38   \n# Recipe Name: Baked Beans Potato Chaat Reci...              30
# 142  \n# Recipe Name: Spicy Matar Masala Recipe\n> ...              30
# 2    \n# Recipe Name:  Aloo Parwal Sabzi (Recipe In...              10
# 8    \n# Recipe Name:  Crispy Palak Pakora Recipe\n...              15
# 55   \n# Recipe Name: Chettinad Style Chilli Gobhi ...              20
# 33   \n# Recipe Name:  Sweet & Spicy Coriander Tadk...              15
# 131  \n# Recipe Name: Sabudana Vada Recipe - Deep F...              15
# 99   \n# Recipe Name: Mooli Aur Kaccha Kela Kofta R...              20
# 67   \n# Recipe Name: Dhaba Style Spicy Ghee Rice R...               5
# 146  \n# Recipe Name: Spring Onion Pakora Recipe - ...              15
# 129  \n# Recipe Name: Sabsige Millet Pulav Recipe\n...              15
# 32   \n# Recipe Name:  Spring Onion Pakoda Recipe\n...              15
# 48   \n# Recipe Name: Carrot And Capsicum Rice Reci...              20
# 107  \n# Recipe Name: No Onion No Garlic Aloo Gajar...              10
# 3    \n# Recipe Name:  Aloo Poha Recipe\n> URL: htt...              20
# 20   \n# Recipe Name:  Methi Matar Pulao (Recipe In...              20
# 134  \n# Recipe Name: Sour Mint Potato Recipe - Tan...              10
# 78   \n# Recipe Name: How To Make Homemade Kashmiri...              15
# 11   \n# Recipe Name:  Green Beans Fry (Recipe In H...              10
# 79   \n# Recipe Name: Indian Spicy Masala Cookie Re...              30
# 23   \n# Recipe Name:  No Onion No Garlic Raw Tomat...              10
# 35   \n# Recipe Name: Aloo Poha Recipe - Potato Poh...              20
# 117  \n# Recipe Name: Pan Fried Onion Pakora Recipe...              10
# 49   \n# Recipe Name: Carrot and Capsicum Rice Reci...              20
# 51   \n# Recipe Name: Chana Pulao Recipe - Spicy Ch...             480
# 89   \n# Recipe Name: Khurchan Mawa Burfi Recipe\n>...              15
# 111  \n# Recipe Name: North East Khapse Recipe (Dee...              20
#
#      CookTimeInMins  TotalTimeInMins  Servings Cuisine        Diet  \
# 84               30               60         4  Indian  Vegetarian
# 114              40               60         4  Indian  Vegetarian
# 65               45               75         4  Indian  Vegetarian
# 155              15               30         4  Indian  Vegetarian
# 98               15               35         4  Indian  Vegetarian
# 27               40               60         4  Indian  Vegetarian
# 115              40               60         4  Indian  Vegetarian
# 75               60               80         6  Indian  Vegetarian
# 130              30               45         2  Indian  Vegetarian
# 137              35               50         3  Indian  Vegetarian
# 6                20               35         4  Indian  Vegetarian
# 74               15               25         2  Indian  Vegetarian
# 54              100              110         2  Indian  Vegetarian
# 62               25               40         5  Indian  Vegetarian
# 37               30               50         4  Indian  Vegetarian
# 128              40               60         6  Indian  Vegetarian
# 96               30               50         4  Indian  Vegetarian
# 143              15               35         5  Indian  Vegetarian
# 90               30               65         4  Indian  Vegetarian
# 31               30               60         4  Indian  Vegetarian
# 112              30               40         3  Indian  Vegetarian
# 73               20               60         4  Indian  Vegetarian
# 116              30               40         4  Indian  Vegetarian
# 38               25               55         4  Indian  Vegetarian
# 142              30               60         4  Indian  Vegetarian
# 2                40               50         6  Indian  Vegetarian
# 8                25               40         5  Indian  Vegetarian
# 55               30               50         4  Indian  Vegetarian
# 33               15               30         2  Indian  Vegetarian
# 131              30               45         4  Indian  Vegetarian
# 99               30               50         4  Indian  Vegetarian
# 67               15               20         2  Indian  Vegetarian
# 146              15               30         4  Indian  Vegetarian
# 129              15               30         3  Indian  Vegetarian
# 32               15               30         4  Indian  Vegetarian
# 48               45               65         2  Indian  Vegetarian
# 107              30               40         4  Indian  Vegetarian
# 3                30               50         4  Indian  Vegetarian
# 20               45               65         4  Indian  Vegetarian
# 134              15               25         2  Indian  Vegetarian
# 78               30               45         2  Indian  Vegetarian
# 11               30               40         2  Indian  Vegetarian
# 79               45               75         6  Indian  Vegetarian
# 23               20               30         6  Indian  Vegetarian
# 35               30               50         4  Indian  Vegetarian
# 117              30               40         4  Indian  Vegetarian
# 49               45               65         2  Indian  Vegetarian
# 51               45              525         3  Indian  Vegetarian
# 89               20               35        10  Indian  Vegetarian
# 111              30               50         4  Indian  Vegetarian
#
#     ComplexityLevel MainIngredient  score  rerank_score
# 84             Hard           rice   0.65          0.85
# 114            Hard        chopped   0.65          0.85
# 65             Hard         cooked   0.57          0.83
# 155            Hard        roasted   0.63          0.83
# 98             Hard         cooked   0.66          0.83
# 27             Hard       Eggplant   0.64          0.82
# 115            Hard          cubes   0.62          0.81
# 75             Hard         (Aloo)   0.64          0.81
# 130            Hard        Pearls)   0.56          0.81
# 137            Hard          Rava)   0.63          0.81
# 6              Hard        chopped   0.65          0.81
# 74           Medium        chopped   0.63          0.80
# 54             Hard        (Maida)   0.64          0.80
# 62           Medium        (Palak)   0.61          0.80
# 37             Hard           Rice   0.58          0.80
# 128            Hard        (besan)   0.61          0.79
# 96             Hard        (besan)   0.61          0.79
# 143            Hard           rice   0.65          0.79
# 90             Hard           Rice   0.63          0.79
# 31             Hard           boil   0.70          0.79
# 112            Hard          rice)   0.62          0.79
# 73             Hard          water   0.62          0.79
# 116            Hard        (besan)   0.61          0.79
# 38             Hard         breads   0.57          0.79
# 142            Hard         boiled   0.63          0.78
# 2              Hard         wedges   0.66          0.78
# 8            Medium        Spinach   0.61          0.78
# 55             Hard        florets   0.55          0.78
# 33           Medium             ले   0.68          0.78
# 131            Hard      overnight   0.58          0.78
# 99             Hard        steamed   0.40          0.78
# 67             Hard        minutes   0.61          0.78
# 146            Hard          bunch   0.63          0.77
# 129            Hard         millet   0.43          0.77
# 32           Medium          flour   0.64          0.77
# 48             Hard           rice   0.59          0.77
# 107            Hard          diced   0.40          0.77
# 3              Hard           poha   0.60          0.77
# 20             Hard           rice   0.59          0.77
# 134          Medium         boiled   0.62          0.77
# 78             Hard        (Jeera)   0.63          0.77
# 11           Medium          beans   0.61          0.77
# 79             Hard        (Maida)   0.61          0.77
# 23           Medium            raw   0.61          0.76
# 35             Hard          rice)   0.41          0.76
# 117            Hard           बेसन   0.63          0.76
# 49             Hard           cook   0.58          0.76
# 51             Hard     Chickpeas)   0.62          0.76
# 89           Medium           ghee   0.57          0.76
# 111            Hard        (Maida)   0.58          0.76

# %%
context = '\n---\n'.join(as_cards(results))


resp = model.generate_content(
    prompt.format(
        llm_persona=llm_persona,
        objective_prompt=objective_prompt,
        user_message=user_message,
        chat_history=chat_history,
        context=context,
    )
).text
print(resp)
# Out:
# Okay, I understand you're looking for a recipe that is high protein, vegetarian, and easy to cook. I can certainly help you find a recipe that fits those requirements from the Indian Food Dataset!
#
# Here are a few options from the dataset that might be of interest:
#
# *   **Dal And Vegetable Kebab Recipe:** This recipe uses kabuli chana, black eyed beans, kala chana, carrot, green bell pepper, potato and onion for a high protein vegetarian meal. Although this recipe takes 75 minutes to cook and has hard complexity level, it is high in protein.
#
# *   **Haryali Seekh Kebab Recipe:** This recipe uses potatoes, broccoli, chana dal, spinach leaves, mint leaves, and coriander leaves for a high protein vegetarian meal. Although this recipe takes 80 minutes to cook and has hard complexity level, it is high in protein.
#
# Could you clarify what kind of dish are you looking for, a main course, or a snack? Based on your preference, I can provide a more tailored recommendation!
#
# If you are looking for a complete meal, I can suggest you pair the **Dal And Vegetable Kebab Recipe** along with **Tomato Onion Cucumber Raita Recipe and Mint Coriander Chutney Recipe** for lunch.
#
# Alternatively, if you are looking for a breakfast recipe, I can suggest you pair the **Haryali Seekh Kebab Recipe** along with **Oats Uttapam Recipe and South Indian Filter Coffee Recipe** for breakfast.

# %%
# Evaluating the LLM response using LLM model as a Judge

judge_prompt = '''
You are a judge that evaluates the LLM response.
Your persona is polite, friendly and helpful.
Your task is to evaluate the LLM response and provide feedback.
Your evaluation should be based on the following criteria:
- Relevance: How relevant is the response to the user query?
- Clarity: How clear is the response?
- Completeness: How complete is the response?
- Usefulness: How useful is the response?
- Creativity: How creative is the response?

Candidate LLM response:

{llm_response}

User Context:

{context}

Knowledge base used:

{knowledge_base}

Your evaluation should be in the following format(all scores out of 10):
- Relevance: <relevance_score>/10
- Clarity: <clarity_score>/10
- Completeness: <completeness_score>/10
- Usefulness: <usefulness_score>/10
- Creativity: <creativity_score>/10
- Overall Score: <overall_score>/10
- Feedback: <feedback>
- Suggestions: <suggestions>
- Improvements: <improvements>
- Additional Notes: <additional_notes>
'''

eval_resp = model.generate_content(
    judge_prompt.format(
        llm_response=resp,
        context=all_user_context,
        knowledge_base=context,
    )
).text

print(eval_resp)
# Out:
# - Relevance: 10/10
# - Clarity: 9/10
# - Completeness: 9/10
# - Usefulness: 9/10
# - Creativity: 7/10
# - Overall Score: 9/10
# - Feedback: Great response with variety of recipes.
# - Suggestions: Look for more options
# - Improvements: If vegetarian is specified, consider reducing total time to cook.
# - Additional Notes: Good response overall.
